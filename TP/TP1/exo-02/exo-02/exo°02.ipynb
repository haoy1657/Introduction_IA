# %% [markdown]
# # Blackjack
# - The library **learning** implements several reinforcement learning algorithm (e.g. sarsa, qlearning, MC, sarsa_lambda, and q_lambda).
# - We will compare the SARSA and Q-learning algorithm to make an agent play the blakjack game.
# - The **objective** of the exercise if for you to understand and explain how both algorithms are used in playing this game. You may use the following reference for SARSA and Q-learning algorithm (https://tcnguyen.github.io/reinforcement_learning/sarsa_vs_q_learning.html)

# %% [markdown]
# ### Import dependencies
# - All python implementations are in the folder **learning**.
# - Read carefully the SARSA and Q-learning implementation (also used in exercise-01). Make some comments about the implementation.

# %%
import numpy as np
from itertools import product

# This functions are inside the folder named learning.
from learning.model_free import Problem
from learning.model_free import sarsa
from learning.model_free import qlearning

# %%
# Write your comments in this cell
'''


in SARSA implementation ( Learning from the current) : The two consecutive state /action pairs and the immediate reward received by the agent while
transitioning from first state to next state determine the updated Q value


for Q learning , the q value is derived from the best action in the next state.
It converge to a solution that is optimal under the assumption that after generationg experience and training , we switch over to the greedy policy 

'''

# greedy ==> cupide , qui ne cherche qu'a maximiser son gain ( pour q learning etant donné qu'on prend le max de q )
# Out:
# '\n\n\nin SARSA implementation ( Learning from the current) : The two consecutive state /action pairs and the immediate reward received by the agent while\ntransitioning from first state to next state determine the updated Q value\n\n\nfor Q learning , the q value is derived from the best action in the next state.\nIt converge to a solution that is optimal under the assumption that after generationg experience and training , we switch over to the greedy policy \n\n'

# %% [markdown]
# ### Create the game class
# - This class inherits from the class **Problem** and adds simple methods to define the components of the game blackjack.
# - As comments, clearly state the components of the Markov Decision Process used for the blackjack game.

# %%
class BlackJack(Problem): #Classe

    def __init__(self): # Methode 
        # Sum of player's cards, dealer's showing card, usable ace
        self.states = [(-1, -1, -1)]
        self.states += [(i, j, k) for (i, j, k) in product(range(12, 22), range(1, 11), [0, 1])]
        self.a = ['hit', 'stick']  # Actions 

        self.states_map = {s: i for i, s in enumerate(self.states)}

        Problem.__init__(self, len(self.states), len(self.a))

    def get_card(self):
        return min(10, np.random.randint(1, 14))

    def sample_initial_state(self):
        my_card = np.random.randint(12, 22)
        dealer_showing = self.get_card()
        usable_ace = np.random.randint(0, 2) # obtenir un as (1) ou non (0)

        return self.states_map[(my_card, dealer_showing, usable_ace)]

    def hand_value(self, sum_cards, usable_ace):
        if usable_ace and sum_cards > 21: # dans le cas ou l'on depasse 21 , on compte l'as comme egal à 1 et non 11 d'ou le fait de soustraire 10
            return sum_cards - 10
        return sum_cards # si l'on ne depasse pas 21 

    def actions(self, s):
        (my_sum, _, usable_ace) = self.states[s]

        if self.hand_value(my_sum, usable_ace) >= 21:
            return [1] # on brule
        else:
            return [0, 1] # on n'a pas brulé , reward de 1

    def is_final(self, s):
        return s == 0

    # Computes the next state and reward pair and whether the state is final
    def state_reward(self, s, a): 
        (my_sum, dealer_card, usable_ace) = self.states[s] # Differents états 
        next_s = self.states_map[(my_sum, dealer_card, usable_ace)] 

        if a == 1:  # Stick
            if self.hand_value(my_sum, usable_ace) > 21:
                return 0, -1 # total des cartes > 21 , on brule , reward negative ( et nulle pour le dealer)

            dealer_sum = dealer_card
            dealer_usable_ace = 0
            if dealer_card == 1: # le dealer tire l'as 
                dealer_sum += 10 # On le compte comme égal à 11 (on ajoute 10 pour faire comprendre a l'algorithme de compter l'as comme 11 puisque le dealer a tiré '1' ; 10+1 =11)
                dealer_usable_ace = 1 # Un as disponible dans le jeu du croupier 

            while self.hand_value(dealer_sum, dealer_usable_ace) < self.hand_value(my_sum, usable_ace): # Total du croupier inferieur à celui du joueur 
                card = self.get_card() # Tire une carte 

                dealer_sum += card # On ajoute cette carte au montant total 
                if card == 1: # si c'est un as 
                    dealer_sum += 10 # compté comme égal à 11

                if card == 1 or dealer_usable_ace: # si le dealer a pioché un as ou a deja un as dans son jeu 
                    if dealer_sum <= 21:
                        dealer_usable_ace = 1 # si la somme est < 21 , on garde notre configuaration
                    else:
                        dealer_sum -= 10 # sinon , l'as vaut 1
                        dealer_usable_ace = 0

                if self.hand_value(dealer_sum, dealer_usable_ace) == self.hand_value(my_sum, usable_ace) == 17: # Pas de reward 
                    return 0, 0

            if self.hand_value(dealer_sum, dealer_usable_ace) > 21: # le dealer brule , on gagne (reward de 1 )
                return 0, 1

            if self.hand_value(dealer_sum, dealer_usable_ace) == self.hand_value(my_sum, usable_ace): # Egalité , personne n'a de reward 
                return 0, 0

            if self.hand_value(dealer_sum, dealer_usable_ace) < self.hand_value(my_sum, usable_ace): # On gagne à la somme  (reward de 1)
                return 0, 1

            # if dealer_sum > my_sum:
            return 0, -1
        else:  # Hit
            card = self.get_card()
            my_sum += card
            if card == 1:
                my_sum += 10

            if card == 1 or usable_ace: # on un as dans notre jeu ou on vient de tirer un as 
                if my_sum <= 21:
                    usable_ace = 1
                else:
                    my_sum -= 10
                    usable_ace = 0

            if self.hand_value(my_sum, usable_ace) > 21:
                return 0, -1

            # Only nonterminal case
            next_s = self.states_map[(my_sum, dealer_card, usable_ace)]
            return next_s, 0

        raise Exception('Unexpected state/action pair') # Error created (exception)

    def print_policy(self, policy):
        print('Usable ace:')
        for i, state in enumerate(self.states):
            if state[2]:
                print('Hand value: {0}, Dealer Showing: {1}, Action: {2}'.format(
                    self.hand_value(state[0], 1), state[1], self.a[policy[i]]))

        print('No usable ace:')
        for i, state in enumerate(self.states):
            if not state[2]:
                print('Hand value: {0}, Dealer Showing: {1}, Action: {2}'.format(
                    self.hand_value(state[0], 0), state[1], self.a[policy[i]]))

    def print_values(self, values):
        for i in range(len(values)):
            print('State {0}. Value: {1}'.format(self.states[i], values[i]))

# %%
# Write your comments in this cell
'''
States : my_sum, dealer_card, usable_ace

Actions : Hit  , Stick 

Rewards : -1,0,1

'''

# %% [markdown]
# ### Main function with different tests
# - Modify this code to test different scenarios and hyperparameters.
# - Also, compare both algorithms by evaluating the evolution of the reward in each trial/step of the process.
# - Comment about the differences.

# %%
# Write your comments in this cell
'''
SARSA : we keep following the same policy , which is the same as behaviour policy 

evaluation of the rewrad per trials : 
[ in the rewrad's plot : state(my sum , dealer card , usable ace) ] --> chaque paire my sum , dealer card est plotée 2 fois pour avoir le cas 1 ou 0 pour l'as 
A better/Higher evolution of rewrads in Sarsa algorithm cause Sarsa is preferable in situations where we care about the agent's performance 
during the process of learning / generating experience 

'''

# %%
def main():
    problem = BlackJack()
    
    print("****************************************************")
    print("SARSA algorithm")
    print("****************************************************")
    pi, v = sarsa(problem, 10000, epsilon=0.1, alpha=0.1, gamma=1.0)
    problem.print_policy(pi)
    problem.print_values(v)

    
    print("****************************************************")
    print("Q learning algorithm")
    print("****************************************************")
    pi, v = qlearning(problem, 10000, epsilon=0.1, alpha=0.1, gamma=1.0)

    problem.print_policy(pi)
    problem.print_values(v)

# %%
# Excuting this line should also plot the evolution of the reward 
# for each algorithm. You may modify any part of the code, just be
# careful to comment what changes are you implementing.

main()
# Out:
# ****************************************************
# SARSA algorithm
# ****************************************************
# Usable ace:
# Hand value: -1, Dealer Showing: -1, Action: hit
# Hand value: 12, Dealer Showing: 1, Action: hit
# Hand value: 12, Dealer Showing: 2, Action: hit
# Hand value: 12, Dealer Showing: 3, Action: hit
# Hand value: 12, Dealer Showing: 4, Action: hit
# Hand value: 12, Dealer Showing: 5, Action: hit
# Hand value: 12, Dealer Showing: 6, Action: hit
# Hand value: 12, Dealer Showing: 7, Action: hit
# Hand value: 12, Dealer Showing: 8, Action: hit
# Hand value: 12, Dealer Showing: 9, Action: hit
# Hand value: 12, Dealer Showing: 10, Action: hit
# Hand value: 13, Dealer Showing: 1, Action: hit
# Hand value: 13, Dealer Showing: 2, Action: hit
# Hand value: 13, Dealer Showing: 3, Action: hit
# Hand value: 13, Dealer Showing: 4, Action: hit
# Hand value: 13, Dealer Showing: 5, Action: hit
# Hand value: 13, Dealer Showing: 6, Action: hit
# Hand value: 13, Dealer Showing: 7, Action: hit
# Hand value: 13, Dealer Showing: 8, Action: hit
# Hand value: 13, Dealer Showing: 9, Action: hit
# Hand value: 13, Dealer Showing: 10, Action: hit
# Hand value: 14, Dealer Showing: 1, Action: hit
# Hand value: 14, Dealer Showing: 2, Action: hit
# Hand value: 14, Dealer Showing: 3, Action: hit
# Hand value: 14, Dealer Showing: 4, Action: hit
# Hand value: 14, Dealer Showing: 5, Action: hit
# Hand value: 14, Dealer Showing: 6, Action: hit
# Hand value: 14, Dealer Showing: 7, Action: hit
# Hand value: 14, Dealer Showing: 8, Action: hit
# Hand value: 14, Dealer Showing: 9, Action: hit
# Hand value: 14, Dealer Showing: 10, Action: hit
# Hand value: 15, Dealer Showing: 1, Action: hit
# Hand value: 15, Dealer Showing: 2, Action: hit
# Hand value: 15, Dealer Showing: 3, Action: hit
# Hand value: 15, Dealer Showing: 4, Action: hit
# Hand value: 15, Dealer Showing: 5, Action: hit
# Hand value: 15, Dealer Showing: 6, Action: hit
# Hand value: 15, Dealer Showing: 7, Action: hit
# Hand value: 15, Dealer Showing: 8, Action: hit
# Hand value: 15, Dealer Showing: 9, Action: hit
# Hand value: 15, Dealer Showing: 10, Action: hit
# Hand value: 16, Dealer Showing: 1, Action: hit
# Hand value: 16, Dealer Showing: 2, Action: stick
# Hand value: 16, Dealer Showing: 3, Action: hit
# Hand value: 16, Dealer Showing: 4, Action: hit
# Hand value: 16, Dealer Showing: 5, Action: hit
# Hand value: 16, Dealer Showing: 6, Action: hit
# Hand value: 16, Dealer Showing: 7, Action: hit
# Hand value: 16, Dealer Showing: 8, Action: hit
# Hand value: 16, Dealer Showing: 9, Action: hit
# Hand value: 16, Dealer Showing: 10, Action: hit
# Hand value: 17, Dealer Showing: 1, Action: hit
# Hand value: 17, Dealer Showing: 2, Action: hit
# Hand value: 17, Dealer Showing: 3, Action: hit
# Hand value: 17, Dealer Showing: 4, Action: stick
# Hand value: 17, Dealer Showing: 5, Action: hit
# Hand value: 17, Dealer Showing: 6, Action: stick
# Hand value: 17, Dealer Showing: 7, Action: hit
# Hand value: 17, Dealer Showing: 8, Action: hit
# Hand value: 17, Dealer Showing: 9, Action: hit
# Hand value: 17, Dealer Showing: 10, Action: hit
# Hand value: 18, Dealer Showing: 1, Action: hit
# Hand value: 18, Dealer Showing: 2, Action: hit
# Hand value: 18, Dealer Showing: 3, Action: stick
# Hand value: 18, Dealer Showing: 4, Action: stick
# Hand value: 18, Dealer Showing: 5, Action: stick
# Hand value: 18, Dealer Showing: 6, Action: stick
# Hand value: 18, Dealer Showing: 7, Action: stick
# Hand value: 18, Dealer Showing: 8, Action: hit
# Hand value: 18, Dealer Showing: 9, Action: hit
# Hand value: 18, Dealer Showing: 10, Action: hit
# Hand value: 19, Dealer Showing: 1, Action: stick
# Hand value: 19, Dealer Showing: 2, Action: stick
# Hand value: 19, Dealer Showing: 3, Action: stick
# Hand value: 19, Dealer Showing: 4, Action: stick
# Hand value: 19, Dealer Showing: 5, Action: hit
# Hand value: 19, Dealer Showing: 6, Action: hit
# Hand value: 19, Dealer Showing: 7, Action: stick
# Hand value: 19, Dealer Showing: 8, Action: stick
# Hand value: 19, Dealer Showing: 9, Action: hit
# Hand value: 19, Dealer Showing: 10, Action: stick
# Hand value: 20, Dealer Showing: 1, Action: stick
# Hand value: 20, Dealer Showing: 2, Action: stick
# Hand value: 20, Dealer Showing: 3, Action: stick
# Hand value: 20, Dealer Showing: 4, Action: stick
# Hand value: 20, Dealer Showing: 5, Action: stick
# Hand value: 20, Dealer Showing: 6, Action: stick
# Hand value: 20, Dealer Showing: 7, Action: stick
# Hand value: 20, Dealer Showing: 8, Action: stick
# Hand value: 20, Dealer Showing: 9, Action: stick
# Hand value: 20, Dealer Showing: 10, Action: stick
# Hand value: 21, Dealer Showing: 1, Action: stick
# Hand value: 21, Dealer Showing: 2, Action: stick
# Hand value: 21, Dealer Showing: 3, Action: stick
# Hand value: 21, Dealer Showing: 4, Action: stick
# Hand value: 21, Dealer Showing: 5, Action: stick
# Hand value: 21, Dealer Showing: 6, Action: stick
# Hand value: 21, Dealer Showing: 7, Action: stick
# Hand value: 21, Dealer Showing: 8, Action: stick
# Hand value: 21, Dealer Showing: 9, Action: stick
# Hand value: 21, Dealer Showing: 10, Action: stick
# No usable ace:
# Hand value: 12, Dealer Showing: 1, Action: hit
# Hand value: 12, Dealer Showing: 2, Action: hit
# Hand value: 12, Dealer Showing: 3, Action: hit
# Hand value: 12, Dealer Showing: 4, Action: hit
# Hand value: 12, Dealer Showing: 5, Action: hit
# Hand value: 12, Dealer Showing: 6, Action: hit
# Hand value: 12, Dealer Showing: 7, Action: hit
# Hand value: 12, Dealer Showing: 8, Action: hit
# Hand value: 12, Dealer Showing: 9, Action: hit
# Hand value: 12, Dealer Showing: 10, Action: hit
# Hand value: 13, Dealer Showing: 1, Action: hit
# Hand value: 13, Dealer Showing: 2, Action: hit
# Hand value: 13, Dealer Showing: 3, Action: hit
# Hand value: 13, Dealer Showing: 4, Action: hit
# Hand value: 13, Dealer Showing: 5, Action: hit
# Hand value: 13, Dealer Showing: 6, Action: hit
# Hand value: 13, Dealer Showing: 7, Action: hit
# Hand value: 13, Dealer Showing: 8, Action: hit
# Hand value: 13, Dealer Showing: 9, Action: hit
# Hand value: 13, Dealer Showing: 10, Action: hit
# Hand value: 14, Dealer Showing: 1, Action: hit
# Hand value: 14, Dealer Showing: 2, Action: hit
# Hand value: 14, Dealer Showing: 3, Action: hit
# Hand value: 14, Dealer Showing: 4, Action: hit
# Hand value: 14, Dealer Showing: 5, Action: hit
# Hand value: 14, Dealer Showing: 6, Action: hit
# Hand value: 14, Dealer Showing: 7, Action: hit
# Hand value: 14, Dealer Showing: 8, Action: hit
# Hand value: 14, Dealer Showing: 9, Action: hit
# Hand value: 14, Dealer Showing: 10, Action: hit
# Hand value: 15, Dealer Showing: 1, Action: stick
# Hand value: 15, Dealer Showing: 2, Action: stick
# Hand value: 15, Dealer Showing: 3, Action: hit
# Hand value: 15, Dealer Showing: 4, Action: stick
# Hand value: 15, Dealer Showing: 5, Action: hit
# Hand value: 15, Dealer Showing: 6, Action: hit
# Hand value: 15, Dealer Showing: 7, Action: hit
# Hand value: 15, Dealer Showing: 8, Action: hit
# Hand value: 15, Dealer Showing: 9, Action: hit
# Hand value: 15, Dealer Showing: 10, Action: hit
# Hand value: 16, Dealer Showing: 1, Action: hit
# Hand value: 16, Dealer Showing: 2, Action: stick
# Hand value: 16, Dealer Showing: 3, Action: stick
# Hand value: 16, Dealer Showing: 4, Action: stick
# Hand value: 16, Dealer Showing: 5, Action: stick
# Hand value: 16, Dealer Showing: 6, Action: stick
# Hand value: 16, Dealer Showing: 7, Action: hit
# Hand value: 16, Dealer Showing: 8, Action: hit
# Hand value: 16, Dealer Showing: 9, Action: stick
# Hand value: 16, Dealer Showing: 10, Action: hit
# Hand value: 17, Dealer Showing: 1, Action: stick
# Hand value: 17, Dealer Showing: 2, Action: stick
# Hand value: 17, Dealer Showing: 3, Action: stick
# Hand value: 17, Dealer Showing: 4, Action: stick
# Hand value: 17, Dealer Showing: 5, Action: stick
# Hand value: 17, Dealer Showing: 6, Action: stick
# Hand value: 17, Dealer Showing: 7, Action: stick
# Hand value: 17, Dealer Showing: 8, Action: stick
# Hand value: 17, Dealer Showing: 9, Action: hit
# Hand value: 17, Dealer Showing: 10, Action: stick
# Hand value: 18, Dealer Showing: 1, Action: stick
# Hand value: 18, Dealer Showing: 2, Action: stick
# Hand value: 18, Dealer Showing: 3, Action: stick
# Hand value: 18, Dealer Showing: 4, Action: stick
# Hand value: 18, Dealer Showing: 5, Action: stick
# Hand value: 18, Dealer Showing: 6, Action: stick
# Hand value: 18, Dealer Showing: 7, Action: stick
# Hand value: 18, Dealer Showing: 8, Action: stick
# Hand value: 18, Dealer Showing: 9, Action: stick
# Hand value: 18, Dealer Showing: 10, Action: stick
# Hand value: 19, Dealer Showing: 1, Action: stick
# Hand value: 19, Dealer Showing: 2, Action: stick
# Hand value: 19, Dealer Showing: 3, Action: stick
# Hand value: 19, Dealer Showing: 4, Action: stick
# Hand value: 19, Dealer Showing: 5, Action: stick
# Hand value: 19, Dealer Showing: 6, Action: stick
# Hand value: 19, Dealer Showing: 7, Action: stick
# Hand value: 19, Dealer Showing: 8, Action: stick
# Hand value: 19, Dealer Showing: 9, Action: stick
# Hand value: 19, Dealer Showing: 10, Action: stick
# Hand value: 20, Dealer Showing: 1, Action: stick
# Hand value: 20, Dealer Showing: 2, Action: stick
# Hand value: 20, Dealer Showing: 3, Action: stick
# Hand value: 20, Dealer Showing: 4, Action: stick
# Hand value: 20, Dealer Showing: 5, Action: stick
# Hand value: 20, Dealer Showing: 6, Action: stick
# Hand value: 20, Dealer Showing: 7, Action: stick
# Hand value: 20, Dealer Showing: 8, Action: stick
# Hand value: 20, Dealer Showing: 9, Action: stick
# Hand value: 20, Dealer Showing: 10, Action: stick
# Hand value: 21, Dealer Showing: 1, Action: stick
# Hand value: 21, Dealer Showing: 2, Action: stick
# Hand value: 21, Dealer Showing: 3, Action: stick
# Hand value: 21, Dealer Showing: 4, Action: stick
# Hand value: 21, Dealer Showing: 5, Action: stick
# Hand value: 21, Dealer Showing: 6, Action: stick
# Hand value: 21, Dealer Showing: 7, Action: stick
# Hand value: 21, Dealer Showing: 8, Action: stick
# Hand value: 21, Dealer Showing: 9, Action: stick
# Hand value: 21, Dealer Showing: 10, Action: stick
# State (-1, -1, -1). Value: 0.0
# State (12, 1, 0). Value: -0.6599534224105644
# State (12, 1, 1). Value: -0.4078543858488877
# State (12, 2, 0). Value: -0.10648303642355897
# State (12, 2, 1). Value: 0.003208490735637705
# State (12, 3, 0). Value: -0.25456107746272877
# State (12, 3, 1). Value: -0.08735568382215805
# State (12, 4, 0). Value: -0.47408515423611786
# State (12, 4, 1). Value: 0.05767305554825055
# State (12, 5, 0). Value: -0.14273508822432768
# State (12, 5, 1). Value: -0.026142589120247327
# State (12, 6, 0). Value: -0.08227219615876781
# State (12, 6, 1). Value: 0.037826682267748886
# State (12, 7, 0). Value: -0.4537958446644183
# State (12, 7, 1). Value: 0.021679127033857958
# State (12, 8, 0). Value: -0.2527465737961692
# State (12, 8, 1). Value: -0.24347094024049387
# State (12, 9, 0). Value: -0.40255615535014483
# State (12, 9, 1). Value: -0.18446281176548077
# State (12, 10, 0). Value: -0.40049443386000466
# State (12, 10, 1). Value: -0.22561514661273382
# State (13, 1, 0). Value: -0.6897987229376075
# State (13, 1, 1). Value: -0.3944485427390117
# State (13, 2, 0). Value: -0.38934520216606217
# State (13, 2, 1). Value: 0.09276693706462767
# State (13, 3, 0). Value: -0.27746782249471597
# State (13, 3, 1). Value: -0.20857952553531467
# State (13, 4, 0). Value: -0.3487709947127947
# State (13, 4, 1). Value: 0.04156256920664868
# State (13, 5, 0). Value: -0.5451516768321919
# State (20, 1, 1). Value: 0.016018944552858017
# State (20, 2, 0). Value: 0.4913972981038004
# State (20, 2, 1). Value: 0.5885245574215899
# State (20, 3, 0). Value: 0.3475834459471506
# State (20, 3, 1). Value: 0.43513891121176035
# State (20, 4, 0). Value: 0.4125641074921093
# State (20, 4, 1). Value: 0.5983838892186344
# State (20, 5, 0). Value: 0.83303803160047
# State (20, 5, 1). Value: 0.48449754247476656
# State (20, 6, 0). Value: 0.494027801335113
# State (20, 6, 1). Value: 0.46982230273043424
# State (20, 7, 0). Value: 0.6943982045931685
# State (20, 7, 1). Value: 0.2632158696159492
# State (20, 8, 0). Value: 0.44535876644279626
# State (20, 8, 1). Value: 0.5253241165128404
# State (20, 9, 0). Value: 0.8616127546989181
# State (20, 9, 1). Value: 0.6559402705564537
# State (20, 10, 0). Value: 0.3244340482694904
# State (20, 10, 1). Value: 0.5592653671575181
# State (21, 1, 0). Value: 0.5739348492140675
# State (21, 1, 1). Value: 0.5724011732988222
# State (21, 2, 0). Value: 0.6781674455822204
# State (21, 2, 1). Value: 0.6046753933125608
# State (21, 3, 0). Value: 0.8468792822788994
# State (21, 3, 1). Value: 0.892660827321911
# State (21, 4, 0). Value: 0.8769975462200634
# State (21, 4, 1). Value: 0.7832811970422651
# State (21, 5, 0). Value: 0.9727447816488185
# State (21, 5, 1). Value: 0.8148291686161037
# State (21, 6, 0). Value: 0.8275117993611736
# State (21, 6, 1). Value: 0.9299882662969872
# State (21, 7, 0). Value: 0.6535329294669496
# State (21, 7, 1). Value: 0.874541811924768
# State (21, 8, 0). Value: 0.8275834075007027
# State (21, 8, 1). Value: 0.8403416030545927
# State (21, 9, 0). Value: 0.9775198876774558
# State (21, 9, 1). Value: 0.9465691878593063
# State (21, 10, 0). Value: 0.7655096120719498
# State (21, 10, 1). Value: 0.9134703760569689
# ****************************************************
# Q learning algorithm
# ****************************************************
# Usable ace:
# Hand value: -1, Dealer Showing: -1, Action: hit
# Hand value: 12, Dealer Showing: 1, Action: stick
# Hand value: 12, Dealer Showing: 2, Action: hit
# Hand value: 12, Dealer Showing: 3, Action: hit
# Hand value: 12, Dealer Showing: 4, Action: hit
# Hand value: 12, Dealer Showing: 5, Action: hit
# Hand value: 12, Dealer Showing: 6, Action: hit
# Hand value: 12, Dealer Showing: 7, Action: hit
# Hand value: 12, Dealer Showing: 8, Action: hit
# Hand value: 12, Dealer Showing: 9, Action: hit
# Hand value: 12, Dealer Showing: 10, Action: hit
# Hand value: 13, Dealer Showing: 1, Action: hit
# Hand value: 13, Dealer Showing: 2, Action: hit
# Hand value: 13, Dealer Showing: 3, Action: hit
# Hand value: 13, Dealer Showing: 4, Action: hit
# Hand value: 13, Dealer Showing: 5, Action: hit
# Hand value: 13, Dealer Showing: 6, Action: hit
# Hand value: 13, Dealer Showing: 7, Action: hit
# Hand value: 13, Dealer Showing: 8, Action: hit
# Hand value: 13, Dealer Showing: 9, Action: hit
# Hand value: 13, Dealer Showing: 10, Action: hit
# Hand value: 14, Dealer Showing: 1, Action: hit
# Hand value: 14, Dealer Showing: 2, Action: hit
# Hand value: 14, Dealer Showing: 3, Action: hit
# Hand value: 14, Dealer Showing: 4, Action: hit
# Hand value: 14, Dealer Showing: 5, Action: hit
# Hand value: 14, Dealer Showing: 6, Action: hit
# Hand value: 14, Dealer Showing: 7, Action: hit
# Hand value: 14, Dealer Showing: 8, Action: hit
# Hand value: 14, Dealer Showing: 9, Action: stick
# Hand value: 14, Dealer Showing: 10, Action: hit
# Hand value: 15, Dealer Showing: 1, Action: hit
# Hand value: 15, Dealer Showing: 2, Action: hit
# Hand value: 15, Dealer Showing: 3, Action: hit
# Hand value: 15, Dealer Showing: 4, Action: hit
# Hand value: 15, Dealer Showing: 5, Action: hit
# Hand value: 15, Dealer Showing: 6, Action: hit
# Hand value: 15, Dealer Showing: 7, Action: hit
# Hand value: 15, Dealer Showing: 8, Action: hit
# Hand value: 15, Dealer Showing: 9, Action: hit
# Hand value: 15, Dealer Showing: 10, Action: hit
# Hand value: 16, Dealer Showing: 1, Action: hit
# Hand value: 16, Dealer Showing: 2, Action: hit
# Hand value: 16, Dealer Showing: 3, Action: hit
# Hand value: 16, Dealer Showing: 4, Action: hit
# Hand value: 16, Dealer Showing: 5, Action: hit
# Hand value: 16, Dealer Showing: 6, Action: hit
# Hand value: 16, Dealer Showing: 7, Action: hit
# Hand value: 16, Dealer Showing: 8, Action: hit
# Hand value: 16, Dealer Showing: 9, Action: hit
# Hand value: 16, Dealer Showing: 10, Action: hit
# Hand value: 17, Dealer Showing: 1, Action: stick
# Hand value: 17, Dealer Showing: 2, Action: hit
# Hand value: 17, Dealer Showing: 3, Action: hit
# Hand value: 17, Dealer Showing: 4, Action: stick
# Hand value: 17, Dealer Showing: 5, Action: hit
# Hand value: 17, Dealer Showing: 6, Action: hit
# Hand value: 17, Dealer Showing: 7, Action: hit
# Hand value: 17, Dealer Showing: 8, Action: hit
# Hand value: 17, Dealer Showing: 9, Action: hit
# Hand value: 17, Dealer Showing: 10, Action: hit
# Hand value: 18, Dealer Showing: 1, Action: hit
# Hand value: 18, Dealer Showing: 2, Action: hit
# Hand value: 18, Dealer Showing: 3, Action: stick
# Hand value: 18, Dealer Showing: 4, Action: hit
# Hand value: 18, Dealer Showing: 5, Action: hit
# Hand value: 18, Dealer Showing: 6, Action: stick
# Hand value: 18, Dealer Showing: 7, Action: stick
# Hand value: 18, Dealer Showing: 8, Action: hit
# Hand value: 18, Dealer Showing: 9, Action: hit
# Hand value: 18, Dealer Showing: 10, Action: hit
# Hand value: 19, Dealer Showing: 1, Action: stick
# Hand value: 19, Dealer Showing: 2, Action: stick
# Hand value: 19, Dealer Showing: 3, Action: hit
# Hand value: 19, Dealer Showing: 4, Action: hit
# Hand value: 19, Dealer Showing: 5, Action: hit
# Hand value: 19, Dealer Showing: 6, Action: hit
# Hand value: 19, Dealer Showing: 7, Action: hit
# Hand value: 19, Dealer Showing: 8, Action: stick
# Hand value: 19, Dealer Showing: 9, Action: hit
# Hand value: 19, Dealer Showing: 10, Action: hit
# Hand value: 20, Dealer Showing: 1, Action: stick
# Hand value: 20, Dealer Showing: 2, Action: stick
# Hand value: 20, Dealer Showing: 3, Action: stick
# Hand value: 20, Dealer Showing: 4, Action: stick
# Hand value: 20, Dealer Showing: 5, Action: stick
# Hand value: 20, Dealer Showing: 6, Action: stick
# Hand value: 20, Dealer Showing: 7, Action: stick
# Hand value: 20, Dealer Showing: 8, Action: stick
# Hand value: 20, Dealer Showing: 9, Action: stick
# Hand value: 20, Dealer Showing: 10, Action: stick
# Hand value: 21, Dealer Showing: 1, Action: stick
# Hand value: 21, Dealer Showing: 2, Action: stick
# Hand value: 21, Dealer Showing: 3, Action: stick
# Hand value: 21, Dealer Showing: 4, Action: stick
# Hand value: 21, Dealer Showing: 5, Action: stick
# Hand value: 21, Dealer Showing: 6, Action: stick
# Hand value: 21, Dealer Showing: 7, Action: stick
# Hand value: 21, Dealer Showing: 8, Action: stick
# Hand value: 21, Dealer Showing: 9, Action: stick
# Hand value: 21, Dealer Showing: 10, Action: stick
# No usable ace:
# Hand value: 12, Dealer Showing: 1, Action: hit
# Hand value: 12, Dealer Showing: 2, Action: hit
# Hand value: 12, Dealer Showing: 3, Action: hit
# Hand value: 12, Dealer Showing: 4, Action: hit
# Hand value: 12, Dealer Showing: 5, Action: hit
# Hand value: 12, Dealer Showing: 6, Action: hit
# Hand value: 12, Dealer Showing: 7, Action: hit
# Hand value: 12, Dealer Showing: 8, Action: hit
# Hand value: 12, Dealer Showing: 9, Action: hit
# Hand value: 12, Dealer Showing: 10, Action: hit
# Hand value: 13, Dealer Showing: 1, Action: hit
# Hand value: 13, Dealer Showing: 2, Action: hit
# Hand value: 13, Dealer Showing: 3, Action: hit
# Hand value: 13, Dealer Showing: 4, Action: hit
# Hand value: 13, Dealer Showing: 5, Action: hit
# Hand value: 13, Dealer Showing: 6, Action: hit
# Hand value: 13, Dealer Showing: 7, Action: hit
# Hand value: 13, Dealer Showing: 8, Action: hit
# Hand value: 13, Dealer Showing: 9, Action: hit
# Hand value: 13, Dealer Showing: 10, Action: hit
# Hand value: 14, Dealer Showing: 1, Action: hit
# Hand value: 14, Dealer Showing: 2, Action: hit
# Hand value: 14, Dealer Showing: 3, Action: hit
# Hand value: 14, Dealer Showing: 4, Action: stick
# Hand value: 14, Dealer Showing: 5, Action: hit
# Hand value: 14, Dealer Showing: 6, Action: stick
# Hand value: 14, Dealer Showing: 7, Action: hit
# Hand value: 14, Dealer Showing: 8, Action: stick
# Hand value: 14, Dealer Showing: 9, Action: hit
# Hand value: 14, Dealer Showing: 10, Action: hit
# Hand value: 15, Dealer Showing: 1, Action: hit
# Hand value: 15, Dealer Showing: 2, Action: hit
# Hand value: 15, Dealer Showing: 3, Action: hit
# Hand value: 15, Dealer Showing: 4, Action: hit
# Hand value: 15, Dealer Showing: 5, Action: hit
# Hand value: 15, Dealer Showing: 6, Action: hit
# Hand value: 15, Dealer Showing: 7, Action: hit
# Hand value: 15, Dealer Showing: 8, Action: hit
# Hand value: 15, Dealer Showing: 9, Action: stick
# Hand value: 15, Dealer Showing: 10, Action: hit
# Hand value: 16, Dealer Showing: 1, Action: hit
# Hand value: 16, Dealer Showing: 2, Action: stick
# Hand value: 16, Dealer Showing: 3, Action: hit
# Hand value: 16, Dealer Showing: 4, Action: hit
# Hand value: 16, Dealer Showing: 5, Action: stick
# Hand value: 16, Dealer Showing: 6, Action: stick
# Hand value: 16, Dealer Showing: 7, Action: hit
# Hand value: 16, Dealer Showing: 8, Action: hit
# Hand value: 16, Dealer Showing: 9, Action: stick
# Hand value: 16, Dealer Showing: 10, Action: hit
# Hand value: 17, Dealer Showing: 1, Action: stick
# Hand value: 17, Dealer Showing: 2, Action: hit
# Hand value: 17, Dealer Showing: 3, Action: stick
# Hand value: 17, Dealer Showing: 4, Action: stick
# Hand value: 17, Dealer Showing: 5, Action: stick
# Hand value: 17, Dealer Showing: 6, Action: stick
# Hand value: 17, Dealer Showing: 7, Action: stick
# Hand value: 17, Dealer Showing: 8, Action: stick
# Hand value: 17, Dealer Showing: 9, Action: hit
# Hand value: 17, Dealer Showing: 10, Action: stick
# Hand value: 18, Dealer Showing: 1, Action: stick
# Hand value: 18, Dealer Showing: 2, Action: stick
# Hand value: 18, Dealer Showing: 3, Action: stick
# Hand value: 18, Dealer Showing: 4, Action: stick
# Hand value: 18, Dealer Showing: 5, Action: stick
# Hand value: 18, Dealer Showing: 6, Action: stick
# Hand value: 18, Dealer Showing: 7, Action: stick
# Hand value: 18, Dealer Showing: 8, Action: stick
# Hand value: 18, Dealer Showing: 9, Action: stick
# Hand value: 18, Dealer Showing: 10, Action: stick
# Hand value: 19, Dealer Showing: 1, Action: stick
# Hand value: 19, Dealer Showing: 2, Action: stick
# Hand value: 19, Dealer Showing: 3, Action: stick
# Hand value: 19, Dealer Showing: 4, Action: stick
# Hand value: 19, Dealer Showing: 5, Action: stick
# Hand value: 19, Dealer Showing: 6, Action: stick
# Hand value: 19, Dealer Showing: 7, Action: stick
# Hand value: 19, Dealer Showing: 8, Action: stick
# Hand value: 19, Dealer Showing: 9, Action: stick
# Hand value: 19, Dealer Showing: 10, Action: stick
# Hand value: 20, Dealer Showing: 1, Action: stick
# Hand value: 20, Dealer Showing: 2, Action: stick
# Hand value: 20, Dealer Showing: 3, Action: stick
# Hand value: 20, Dealer Showing: 4, Action: stick
# Hand value: 20, Dealer Showing: 5, Action: stick
# Hand value: 20, Dealer Showing: 6, Action: stick
# Hand value: 20, Dealer Showing: 7, Action: stick
# Hand value: 20, Dealer Showing: 8, Action: stick
# Hand value: 20, Dealer Showing: 9, Action: stick
# Hand value: 20, Dealer Showing: 10, Action: stick
# Hand value: 21, Dealer Showing: 1, Action: stick
# Hand value: 21, Dealer Showing: 2, Action: stick
# Hand value: 21, Dealer Showing: 3, Action: stick
# Hand value: 21, Dealer Showing: 4, Action: stick
# Hand value: 21, Dealer Showing: 5, Action: stick
# Hand value: 21, Dealer Showing: 6, Action: stick
# Hand value: 21, Dealer Showing: 7, Action: stick
# Hand value: 21, Dealer Showing: 8, Action: stick
# Hand value: 21, Dealer Showing: 9, Action: stick
# Hand value: 21, Dealer Showing: 10, Action: stick
# State (-1, -1, -1). Value: 0.0
# State (12, 1, 0). Value: -0.6785733679032754
# State (12, 1, 1). Value: -0.40951000000000004
# State (12, 2, 0). Value: -0.2501498683758443
